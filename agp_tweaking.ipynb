# %%
import pandas as pd

# %%
df = pd.read_csv('mMarFla1.HiC.combined.decontam.20240513.hificovg.pretext.agp_2',
                 sep='\t',
                 comment="#",
                 names = [
                    "Object", "Object_begin", "Object_end", "Part_number",
                    "Component_type", "Component_id", "Component_begin",
                    "Component_end", "Orientation","mod","paint","hap","ex1","ex2"
                    ])

# %%
df
# Out:
#           Object  Object_begin  Object_end  Part_number Component_type  \
# 0     Scaffold_1             1          10            1              W
# 1     Scaffold_1            11          20            2              U
# 2     Scaffold_1            11          20            3              W
# 3     Scaffold_1            21          30            4              U
# 4     Scaffold_1            21          30            5              W
# 5     Scaffold_2             1          10            1              W
# 6     Scaffold_2            11          20            2              U
# 7     Scaffold_2            21          30            3              W
# 8     Scaffold_2            31          40            4              U
# 9     Scaffold_2            41          50            5              W
# 10  Scaffold_600             1          10            1              W
# 11  Scaffold_601             1          10            1              W
# 12  Scaffold_609             1          10            1              W
#
#         Component_id Component_begin Component_end         Orientation  \
# 0      H1.scaffold_1               1            10                   +
# 1                100        scaffold           yes  proximity_ligation
# 2      H1.scaffold_1              11            20                   -
# 3                100        scaffold           yes  proximity_ligation
# 4      H1.scaffold_1              21            30                   +
# 5      H2.scaffold_1               1            10                   +
# 6                100        scaffold           yes  proximity_ligation
# 7      H2.scaffold_1              11            20                   -
# 8                100        scaffold           yes  proximity_ligation
# 9      H2.scaffold_1              21            30                   +
# 10  H1.scaffold_1099               1            10                   +
# 11  H1.scaffold_1132               1            10                   +
# 12   H2.scaffold_542               1            10                   +
#
#         mod  paint                    hap  ex1  ex2
# 0   Painted  Hap_1           Super1_Hap_1  NaN  NaN
# 1       NaN    NaN           Super1_Hap_1  NaN  NaN
# 2   Painted    NaN           Super1_Hap_1  NaN  NaN
# 3       NaN    NaN           Super1_Hap_1  NaN  NaN
# 4   Painted    NaN           Super1_Hap_1  NaN  NaN
# 5   Painted  Hap_2           Super1_Hap_2  NaN  NaN
# 6       NaN    NaN           Super1_Hap_2  NaN  NaN
# 7   Painted    NaN           Super1_Hap_2  NaN  NaN
# 8       NaN    NaN           Super1_Hap_2  NaN  NaN
# 9   Painted    NaN  Super_2_Hap_1_Unloc_1  NaN  NaN
# 10      NaN    NaN                    NaN  NaN  NaN
# 11      NaN    NaN                    NaN  NaN  NaN
# 12      NaN    NaN                    NaN  NaN  NaN

# %%
df = df[(df['Object']=='Scaffold_1') | (df['Object']=='Scaffold_2') | (df['Object']=='Scaffold_3') | (df['Object']=='Scaffold_4')]

# %%
df
# Out:
#         Object  Object_begin  Object_end  Part_number Component_type  \
# 0   Scaffold_1             1   163714215            1              W
# 1   Scaffold_1     163714216   163714315            2              U
# 2   Scaffold_1     163714316   170187104            3              W
# 3   Scaffold_1     170187105   170187204            4              U
# 4   Scaffold_1     170187205   220706538            5              W
# 5   Scaffold_2             1   153294602            1              W
# 6   Scaffold_2     153294603   153294702            2              U
# 7   Scaffold_2     153294703   160398983            3              W
# 8   Scaffold_2     160398984   160399083            4              U
# 9   Scaffold_2     160399084   167029746            5              W
# 10  Scaffold_2     167029747   167029846            6              U
# 11  Scaffold_2     167029847   170187304            7              W
# 12  Scaffold_2     170187305   170187404            8              U
# 13  Scaffold_2     170187405   215970550            9              W
# 14  Scaffold_3             1   128666427            1              W
# 15  Scaffold_3     128666428   128666527            2              U
# 16  Scaffold_3     128666528   129455891            3              W
# 17  Scaffold_3     129455892   129455991            4              U
# 18  Scaffold_3     129455992   129771736            5              W
# 19  Scaffold_3     129771737   129771836            6              U
# 20  Scaffold_3     129771837   130245454            7              W
# 21  Scaffold_3     130245455   130245554            8              U
# 22  Scaffold_3     130245555   130561299            9              W
# 23  Scaffold_3     130561300   130561399           10              U
# 24  Scaffold_3     130561400   131666509           11              W
# 25  Scaffold_3     131666510   131666609           12              U
# 26  Scaffold_3     131666610   132298100           13              W
# 27  Scaffold_3     132298101   132298200           14              U
# 28  Scaffold_3     132298201   204288250           15              W
# 29  Scaffold_3     204288251   204288350           16              U
# 30  Scaffold_3     204288351   204604095           17              W
# 31  Scaffold_3     204604096   204604195           18              U
# 32  Scaffold_3     204604196   204919940           19              W
# 33  Scaffold_4             1      947237            1              W
# 34  Scaffold_4        947238      947337            2              U
# 35  Scaffold_4        947338   128982272            3              W
# 36  Scaffold_4     128982273   128982372            4              U
# 37  Scaffold_4     128982373   129613863            5              W
# 38  Scaffold_4     129613864   129613963            6              U
# 39  Scaffold_4     129613964   131350565            7              W
# 40  Scaffold_4     131350566   131350665            8              U
# 41  Scaffold_4     131350666   131824283            9              W
# 42  Scaffold_4     131824284   131824383           10              U
# 43  Scaffold_4     131824384   203814434           11              W
# 44  Scaffold_4     203814435   203814534           12              U
# 45  Scaffold_4     203814535   204130279           13              W
# 46  Scaffold_4     204130280   204130379           14              U
# 47  Scaffold_4     204130380   204446124           15              W
# 48  Scaffold_4     204446125   204446224           16              U
# 49  Scaffold_4     204446225   204761969           17              W
# 50  Scaffold_4     204761970   204762069           18              U
# 51  Scaffold_4     204762070   205077814           19              W
#
#        Component_id Component_begin Component_end         Orientation  \
# 0     H1.scaffold_1               1     163714215                   +
# 1               100        scaffold           yes  proximity_ligation
# 2     H1.scaffold_1       163714216     170187004                   -
# 3               100        scaffold           yes  proximity_ligation
# 4     H1.scaffold_1       170187005     220706338                   +
# 5     H2.scaffold_1               1     153294602                   +
# 6               100        scaffold           yes  proximity_ligation
# 7    H2.scaffold_24               1       7104281                   +
# 8               100        scaffold           yes  proximity_ligation
# 9     H2.scaffold_1       153294603     159925265                   +
# 10              100        scaffold           yes  proximity_ligation
# 11    H2.scaffold_1       159925266     163082723                   -
# 12              100        scaffold           yes  proximity_ligation
# 13    H2.scaffold_1       163082724     208865869                   +
# 14    H1.scaffold_2        71990051     200656477                   -
# 15              100        scaffold           yes  proximity_ligation
# 16   H1.scaffold_61               1        789364                   -
# 17              100        scaffold           yes  proximity_ligation
# 18  H1.scaffold_147               1        315745                   +
# 19              100        scaffold           yes  proximity_ligation
# 20  H1.scaffold_124               1        473618                   -
# 21              100        scaffold           yes  proximity_ligation
# 22  H1.scaffold_156               1        315745                   +
# 23              100        scaffold           yes  proximity_ligation
# 24   H2.scaffold_46               1       1105110                   +
# 25              100        scaffold           yes  proximity_ligation
# 26   H1.scaffold_86               1        631491                   +
# 27              100        scaffold           yes  proximity_ligation
# 28    H1.scaffold_2               1      71990050                   -
# 29              100        scaffold           yes  proximity_ligation
# 30  H1.scaffold_158               1        315745                   -
# 31              100        scaffold           yes  proximity_ligation
# 32  H1.scaffold_140               1        315745                   -
# 33   H2.scaffold_47               1        947237                   +
# 34              100        scaffold           yes  proximity_ligation
# 35    H2.scaffold_2               1     128034935                   +
# 36              100        scaffold           yes  proximity_ligation
# 37   H2.scaffold_63               1        631491                   -
# 38              100        scaffold           yes  proximity_ligation
# 39   H2.scaffold_36               1       1736602                   +
# 40              100        scaffold           yes  proximity_ligation
# 41   H2.scaffold_90               1        473618                   +
# 42              100        scaffold           yes  proximity_ligation
# 43    H2.scaffold_2       128034936     200024986                   +
# 44              100        scaffold           yes  proximity_ligation
# 45  H2.scaffold_109               1        315745                   -
# 46              100        scaffold           yes  proximity_ligation
# 47  H2.scaffold_141               1        315745                   -
# 48              100        scaffold           yes  proximity_ligation
# 49  H2.scaffold_136               1        315745                   -
# 50              100        scaffold           yes  proximity_ligation
# 51  H1.scaffold_150               1        315745                   +
#
#         mod  paint  hap  ex1  ex2
# 0   Painted  Hap_1  NaN  NaN  NaN
# 1       NaN    NaN  NaN  NaN  NaN
# 2   Painted    NaN  NaN  NaN  NaN
# 3       NaN    NaN  NaN  NaN  NaN
# 4   Painted    NaN  NaN  NaN  NaN
# 5   Painted  Hap_2  NaN  NaN  NaN
# 6       NaN    NaN  NaN  NaN  NaN
# 7   Painted    NaN  NaN  NaN  NaN
# 8       NaN    NaN  NaN  NaN  NaN
# 9   Painted    NaN  NaN  NaN  NaN
# 10      NaN    NaN  NaN  NaN  NaN
# 11  Painted    NaN  NaN  NaN  NaN
# 12      NaN    NaN  NaN  NaN  NaN
# 13  Painted    NaN  NaN  NaN  NaN
# 14  Painted  Hap_1  NaN  NaN  NaN
# 15      NaN    NaN  NaN  NaN  NaN
# 16  Painted    NaN  NaN  NaN  NaN
# 17      NaN    NaN  NaN  NaN  NaN
# 18  Painted    NaN  NaN  NaN  NaN
# 19      NaN    NaN  NaN  NaN  NaN
# 20  Painted    NaN  NaN  NaN  NaN
# 21      NaN    NaN  NaN  NaN  NaN
# 22  Painted    NaN  NaN  NaN  NaN
# 23      NaN    NaN  NaN  NaN  NaN
# 24  Painted    NaN  NaN  NaN  NaN
# 25      NaN    NaN  NaN  NaN  NaN
# 26  Painted    NaN  NaN  NaN  NaN
# 27      NaN    NaN  NaN  NaN  NaN
# 28  Painted    NaN  NaN  NaN  NaN
# 29      NaN    NaN  NaN  NaN  NaN
# 30  Painted    NaN  NaN  NaN  NaN
# 31      NaN    NaN  NaN  NaN  NaN
# 32  Painted  Unloc  NaN  NaN  NaN
# 33  Painted  Hap_2  NaN  NaN  NaN
# 34      NaN    NaN  NaN  NaN  NaN
# 35  Painted    NaN  NaN  NaN  NaN
# 36      NaN    NaN  NaN  NaN  NaN
# 37  Painted    NaN  NaN  NaN  NaN
# 38      NaN    NaN  NaN  NaN  NaN
# 39  Painted    NaN  NaN  NaN  NaN
# 40      NaN    NaN  NaN  NaN  NaN
# 41  Painted    NaN  NaN  NaN  NaN
# 42      NaN    NaN  NaN  NaN  NaN
# 43  Painted    NaN  NaN  NaN  NaN
# 44      NaN    NaN  NaN  NaN  NaN
# 45  Painted    NaN  NaN  NaN  NaN
# 46      NaN    NaN  NaN  NaN  NaN
# 47  Painted    NaN  NaN  NaN  NaN
# 48      NaN    NaN  NaN  NaN  NaN
# 49  Painted  Unloc  NaN  NaN  NaN
# 50      NaN    NaN  NaN  NaN  NaN
# 51  Painted  Unloc  NaN  NaN  NaN

# %%
# Concatenate
haplotype = []
for _, row in df.iterrows():
    if pd.notna(row['hap']):
        haplotype.append(f"Super_{hap_counters[current_hap] - 1}_{current_hap}")

# %%
df.paint.unique()
# Out:
# array(['Hap_1', nan, 'Hap_2', 'Unloc'], dtype=object)

# %%
# Create a new column with Super IDs
hap_counters = {'Hap_1': 1, 'Hap_2': 1}
unloc_counter = 1
current_hap = None
group_ids = []

# Iterate over rows to assign groupID
for _, row in df.iterrows():
    if row["Orientation"] == "proximity_ligation":
        group_ids.append(group_id)
        continue

    paint_value = row["paint"]

    if paint_value in hap_counters:
        # New group for this haplotype
        current_hap = paint_value
        group_id = f"Super_{hap_counters[current_hap]}_{paint_value}"
        hap_counters[current_hap] += 1  # Increment the counter for the haplotype
    elif paint_value == "Unloc" and current_hap:
        # "Unloc" case, no increment in main hap counter
        group_id = f"Super_{hap_counters[current_hap] - 1}_{current_hap}_Unloc_{unloc_counter}"
        unloc_counter += 1  # Increment the Unloc counter within the group
    elif current_hap:
        # Continuation of the current group without new haplotype value
        group_id = f"Super_{hap_counters[current_hap] - 1}_{current_hap}"
        unloc_counter = 1  # Reset Unloc counter if no "Unloc" value

    group_ids.append(group_id)

# Assign the groupID column to the dataframe
df["groupID"] = group_ids

# %%
df
# Out:
#         Object  Object_begin  Object_end  Part_number Component_type  \
# 0   Scaffold_1             1   163714215            1              W
# 1   Scaffold_1     163714216   163714315            2              U
# 2   Scaffold_1     163714316   170187104            3              W
# 3   Scaffold_1     170187105   170187204            4              U
# 4   Scaffold_1     170187205   220706538            5              W
# 5   Scaffold_2             1   153294602            1              W
# 6   Scaffold_2     153294603   153294702            2              U
# 7   Scaffold_2     153294703   160398983            3              W
# 8   Scaffold_2     160398984   160399083            4              U
# 9   Scaffold_2     160399084   167029746            5              W
# 10  Scaffold_2     167029747   167029846            6              U
# 11  Scaffold_2     167029847   170187304            7              W
# 12  Scaffold_2     170187305   170187404            8              U
# 13  Scaffold_2     170187405   215970550            9              W
# 14  Scaffold_3             1   128666427            1              W
# 15  Scaffold_3     128666428   128666527            2              U
# 16  Scaffold_3     128666528   129455891            3              W
# 17  Scaffold_3     129455892   129455991            4              U
# 18  Scaffold_3     129455992   129771736            5              W
# 19  Scaffold_3     129771737   129771836            6              U
# 20  Scaffold_3     129771837   130245454            7              W
# 21  Scaffold_3     130245455   130245554            8              U
# 22  Scaffold_3     130245555   130561299            9              W
# 23  Scaffold_3     130561300   130561399           10              U
# 24  Scaffold_3     130561400   131666509           11              W
# 25  Scaffold_3     131666510   131666609           12              U
# 26  Scaffold_3     131666610   132298100           13              W
# 27  Scaffold_3     132298101   132298200           14              U
# 28  Scaffold_3     132298201   204288250           15              W
# 29  Scaffold_3     204288251   204288350           16              U
# 30  Scaffold_3     204288351   204604095           17              W
# 31  Scaffold_3     204604096   204604195           18              U
# 32  Scaffold_3     204604196   204919940           19              W
# 33  Scaffold_4             1      947237            1              W
# 34  Scaffold_4        947238      947337            2              U
# 35  Scaffold_4        947338   128982272            3              W
# 36  Scaffold_4     128982273   128982372            4              U
# 37  Scaffold_4     128982373   129613863            5              W
# 38  Scaffold_4     129613864   129613963            6              U
# 39  Scaffold_4     129613964   131350565            7              W
# 40  Scaffold_4     131350566   131350665            8              U
# 41  Scaffold_4     131350666   131824283            9              W
# 42  Scaffold_4     131824284   131824383           10              U
# 43  Scaffold_4     131824384   203814434           11              W
# 44  Scaffold_4     203814435   203814534           12              U
# 45  Scaffold_4     203814535   204130279           13              W
# 46  Scaffold_4     204130280   204130379           14              U
# 47  Scaffold_4     204130380   204446124           15              W
# 48  Scaffold_4     204446125   204446224           16              U
# 49  Scaffold_4     204446225   204761969           17              W
# 50  Scaffold_4     204761970   204762069           18              U
# 51  Scaffold_4     204762070   205077814           19              W
#
#        Component_id Component_begin Component_end         Orientation  \
# 0     H1.scaffold_1               1     163714215                   +
# 1               100        scaffold           yes  proximity_ligation
# 2     H1.scaffold_1       163714216     170187004                   -
# 3               100        scaffold           yes  proximity_ligation
# 4     H1.scaffold_1       170187005     220706338                   +
# 5     H2.scaffold_1               1     153294602                   +
# 6               100        scaffold           yes  proximity_ligation
# 7    H2.scaffold_24               1       7104281                   +
# 8               100        scaffold           yes  proximity_ligation
# 9     H2.scaffold_1       153294603     159925265                   +
# 10              100        scaffold           yes  proximity_ligation
# 11    H2.scaffold_1       159925266     163082723                   -
# 12              100        scaffold           yes  proximity_ligation
# 13    H2.scaffold_1       163082724     208865869                   +
# 14    H1.scaffold_2        71990051     200656477                   -
# 15              100        scaffold           yes  proximity_ligation
# 16   H1.scaffold_61               1        789364                   -
# 17              100        scaffold           yes  proximity_ligation
# 18  H1.scaffold_147               1        315745                   +
# 19              100        scaffold           yes  proximity_ligation
# 20  H1.scaffold_124               1        473618                   -
# 21              100        scaffold           yes  proximity_ligation
# 22  H1.scaffold_156               1        315745                   +
# 23              100        scaffold           yes  proximity_ligation
# 24   H2.scaffold_46               1       1105110                   +
# 25              100        scaffold           yes  proximity_ligation
# 26   H1.scaffold_86               1        631491                   +
# 27              100        scaffold           yes  proximity_ligation
# 28    H1.scaffold_2               1      71990050                   -
# 29              100        scaffold           yes  proximity_ligation
# 30  H1.scaffold_158               1        315745                   -
# 31              100        scaffold           yes  proximity_ligation
# 32  H1.scaffold_140               1        315745                   -
# 33   H2.scaffold_47               1        947237                   +
# 34              100        scaffold           yes  proximity_ligation
# 35    H2.scaffold_2               1     128034935                   +
# 36              100        scaffold           yes  proximity_ligation
# 37   H2.scaffold_63               1        631491                   -
# 38              100        scaffold           yes  proximity_ligation
# 39   H2.scaffold_36               1       1736602                   +
# 40              100        scaffold           yes  proximity_ligation
# 41   H2.scaffold_90               1        473618                   +
# 42              100        scaffold           yes  proximity_ligation
# 43    H2.scaffold_2       128034936     200024986                   +
# 44              100        scaffold           yes  proximity_ligation
# 45  H2.scaffold_109               1        315745                   -
# 46              100        scaffold           yes  proximity_ligation
# 47  H2.scaffold_141               1        315745                   -
# 48              100        scaffold           yes  proximity_ligation
# 49  H2.scaffold_136               1        315745                   -
# 50              100        scaffold           yes  proximity_ligation
# 51  H1.scaffold_150               1        315745                   +
#
#         mod  paint  hap  ex1  ex2                groupID
# 0   Painted  Hap_1  NaN  NaN  NaN          Super_1_Hap_1
# 1       NaN    NaN  NaN  NaN  NaN          Super_1_Hap_1
# 2   Painted    NaN  NaN  NaN  NaN          Super_1_Hap_1
# 3       NaN    NaN  NaN  NaN  NaN          Super_1_Hap_1
# 4   Painted    NaN  NaN  NaN  NaN          Super_1_Hap_1
# 5   Painted  Hap_2  NaN  NaN  NaN          Super_1_Hap_2
# 6       NaN    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 7   Painted    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 8       NaN    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 9   Painted    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 10      NaN    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 11  Painted    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 12      NaN    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 13  Painted    NaN  NaN  NaN  NaN          Super_1_Hap_2
# 14  Painted  Hap_1  NaN  NaN  NaN          Super_2_Hap_1
# 15      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 16  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 17      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 18  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 19      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 20  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 21      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 22  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 23      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 24  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 25      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 26  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 27      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 28  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 29      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 30  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 31      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_1
# 32  Painted  Unloc  NaN  NaN  NaN  Super_2_Hap_1_Unloc_1
# 33  Painted  Hap_2  NaN  NaN  NaN          Super_2_Hap_2
# 34      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 35  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 36      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 37  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 38      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 39  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 40      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 41  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 42      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 43  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 44      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 45  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 46      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 47  Painted    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 48      NaN    NaN  NaN  NaN  NaN          Super_2_Hap_2
# 49  Painted  Unloc  NaN  NaN  NaN  Super_2_Hap_2_Unloc_1
# 50      NaN    NaN  NaN  NaN  NaN  Super_2_Hap_2_Unloc_1
# 51  Painted  Unloc  NaN  NaN  NaN  Super_2_Hap_2_Unloc_2

# %%
# Install Biopython v1.81
# !pip install biopython==1.81



# Install pandas (latest version)
# !pip install pandas

import numpy as np
# Out:
# Collecting biopython==1.81
#   Downloading biopython-1.81-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython==1.81) (2.0.2)
# Downloading biopython-1.81-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.1 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.81
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os

# -------------------------------
# Part 1: Generate a new AGP file (new_dummy.agp)
# -------------------------------

agp_filename = "new_dummy.agp"

with open(agp_filename, "w") as f:
    # Write a header comment line with column titles (optional for clarity)
    header_titles = "# Object\tObject_Begin\tObject_End\tPart_Number\tComponent_Type\tComponent_ID\tComponent_Begin\tComponent_End\tOrientation\tComment\tExtra_info\tCol12\tCol13\tCol14\tGroup ID"
    f.write(header_titles + "\n")

    # --- Head Records (10 records) ---
    # Define the original head records (each with 11 columns)
    head_records = [
        # Record 1: set col2=1, col3=10
        ["Scaffold_1", "1", "10", "1", "W", "H1.scaffold_1", "1", "10", "+", "Painted", "Hap_1"],
        # Record 2: dummy values (e.g., 11-20)
        ["Scaffold_1", "11", "20", "2", "U", "100", "scaffold", "yes", "proximity_ligation", "", ""],
        # Record 3: set col2=11, col3=20
        ["Scaffold_1", "11", "20", "3", "W", "H1.scaffold_1", "11", "20", "-", "Painted", ""],
        # Record 4: dummy values (e.g., 21-30)
        ["Scaffold_1", "21", "30", "4", "U", "100", "scaffold", "yes", "proximity_ligation", "", ""],
        # Record 5: set col2=21, col3=30
        ["Scaffold_1", "21", "30", "5", "W", "H1.scaffold_1", "21", "30", "+", "Painted", ""],
        # Record 6: set col2=1, col3=10
        ["Scaffold_2", "1", "10", "1", "W", "H2.scaffold_1", "1", "10", "+", "Painted", "Hap_2"],
        # Record 7: dummy values (e.g., 11-20)
        ["Scaffold_2", "11", "20", "2", "U", "100", "scaffold", "yes", "proximity_ligation", "", ""],
        # Record 8: dummy values (e.g., 21-30)
        ["Scaffold_2", "21", "30", "3", "W", "H2.scaffold_1", "11", "20", "-", "Painted", ""],
        # Record 9: dummy values (e.g., 31-40)
        ["Scaffold_2", "31", "40", "4", "U", "100", "scaffold", "yes", "proximity_ligation", "", ""],
        # Record 10: dummy values (e.g., 41-50)
        ["Scaffold_2", "41", "50", "5", "W", "H1.scaffold_1", "21", "30", "+", "Painted", ""]
    ]

    # Define the Group ID values for head records:
    group_ids = [
        "Super1_Hap_1",   # Record 1
        "Super1_Hap_1",   # Record 2
        "Super1_Hap_1",   # Record 3
        "Super1_Hap_1",   # Record 4
        "Super1_Hap_1",   # Record 5
        "Super1_Hap_2",   # Record 6
        "Super1_Hap_2",   # Record 7
        "Super1_Hap_2",   # Record 8
        "Super1_Hap_2",   # Record 9
        "Super_2_Hap_1_Unloc_1"  # Record 10
    ]

    # For each head record, pad with 3 "NaN" values (columns 12, 13, 14) and then add the Group ID as the 15th column.
    for i, rec in enumerate(head_records):
        padded_record = rec + ["NaN", "NaN", "NaN"] + [group_ids[i]]
        f.write("\t".join(padded_record) + "\n")

    # --- Tail Records (3 records) ---
    # Tail records remain unchanged.
    tail_records = [
        "Scaffold_600\t1\t10\t1\tW\tH1.scaffold_1099\t1\t10\t+",
        "Scaffold_601\t1\t10\t1\tW\tH1.scaffold_1132\t1\t10\t+",
        "Scaffold_609\t1\t10\t1\tW\tH2.scaffold_542\t1\t10\t+"
    ]

    for rec in tail_records:
        f.write(rec + "\n")

print(f"New AGP file '{agp_filename}' generated.\n")

# -------------------------------
# Part 2: Generate a dummy FASTA file (dummy.fasta)
# -------------------------------

fasta_filename = "dummy.fasta"
with open(fasta_filename, "w") as f:
    f.write(">H1.scaffold_1\n")
    f.write("AAACCCGGGGGGAAAAAAGGGGGGGGAAAAACCCCGACGACGACGACCCGGGAAACCGGGAACCCGGGGCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG\n")

    f.write(">H2.scaffold_1\n")
    f.write("GGGCCCAAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA\n")

    f.write(">H1.scaffold_1099\n")
    f.write("A" * 12 + "\n")

    f.write(">H1.scaffold_1132\n")
    f.write("G" * 10 + "\n")

    f.write(">H2.scaffold_542\n")
    f.write("CCCGGGAAAAAAAAAAGCAGCAGCAGCGAGCGACGACGA" + "\n")

print(f"Dummy FASTA file '{fasta_filename}' generated.\n")

# -------------------------------
# Part 3: Print contents of both files
# -------------------------------

print("Contents of new_dummy.agp:\n")
with open(agp_filename, "r") as f:
    print(f.read())

print("\nContents of dummy.fasta:\n")
with open(fasta_filename, "r") as f:
    print(f.read())
# Out:
# New AGP file 'new_dummy.agp' generated.
#
# Dummy FASTA file 'dummy.fasta' generated.
#
# Contents of new_dummy.agp:
#
# # Object	Object_Begin	Object_End	Part_Number	Component_Type	Component_ID	Component_Begin	Component_End	Orientation	Comment	Extra_info	Col12	Col13	Col14	Group ID
# Scaffold_1	1	10	1	W	H1.scaffold_1	1	10	+	Painted	Hap_1	NaN	NaN	NaN	Super1_Hap_1
# Scaffold_1	11	20	2	U	100	scaffold	yes	proximity_ligation			NaN	NaN	NaN	Super1_Hap_1
# Scaffold_1	11	20	3	W	H1.scaffold_1	11	20	-	Painted		NaN	NaN	NaN	Super1_Hap_1
# Scaffold_1	21	30	4	U	100	scaffold	yes	proximity_ligation			NaN	NaN	NaN	Super1_Hap_1
# Scaffold_1	21	30	5	W	H1.scaffold_1	21	30	+	Painted		NaN	NaN	NaN	Super1_Hap_1
# Scaffold_2	1	10	1	W	H2.scaffold_1	1	10	+	Painted	Hap_2	NaN	NaN	NaN	Super1_Hap_2
# Scaffold_2	11	20	2	U	100	scaffold	yes	proximity_ligation			NaN	NaN	NaN	Super1_Hap_2
# Scaffold_2	21	30	3	W	H2.scaffold_1	11	20	-	Painted		NaN	NaN	NaN	Super1_Hap_2
# Scaffold_2	31	40	4	U	100	scaffold	yes	proximity_ligation			NaN	NaN	NaN	Super1_Hap_2
# Scaffold_2	41	50	5	W	H1.scaffold_1	21	30	+	Painted		NaN	NaN	NaN	Super_2_Hap_1_Unloc_1
# Scaffold_600	1	10	1	W	H1.scaffold_1099	1	10	+
# Scaffold_601	1	10	1	W	H1.scaffold_1132	1	10	+
# Scaffold_609	1	10	1	W	H2.scaffold_542	1	10	+
#
#
# Contents of dummy.fasta:
#
# >H1.scaffold_1
# AAACCCGGGGGGAAAAAAGGGGGGGGAAAAACCCCGACGACGACGACCCGGGAAACCGGGAACCCGGGGCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
# >H2.scaffold_1
# GGGCCCAAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# >H1.scaffold_1099
# AAAAAAAAAAAA
# >H1.scaffold_1132
# GGGGGGGGGG
# >H2.scaffold_542
# CCCGGGAAAAAAAAAAGCAGCAGCAGCGAGCGACGACGA

# %%
import pandas as pd
df = pd.read_csv('new_dummy.agp',
                 sep='\t',
                 comment="#",
                 names = [
                    "Object", "Object_begin", "Object_end", "Part_number",
                    "Component_type", "Component_id", "Component_begin",
                    "Component_end", "Orientation","mod","paint","hap","ex1","ex2","Group_ID"
                    ])

# %%
import os
import pandas as pd
from Bio import SeqIO

# Create output folders if they don't exist.
os.makedirs("hap_1", exist_ok=True)
os.makedirs("hap_2", exist_ok=True)

# Load the FASTA file as a dictionary.
fasta_file = "dummy.fasta"  # your FASTA file name
fasta_dict = SeqIO.to_dict(SeqIO.parse(fasta_file, "fasta"))

# Assume your DataFrame is loaded as df.
# For example:
# df = pd.read_csv("data.csv", header=None)

# Fixed output file names.
output_file_h1 = os.path.join("hap_1", "Hap_1.fasta")
output_file_h2 = os.path.join("hap_2", "Hap_2.fasta")

# Create empty output files.
open(output_file_h1, "w").close()
open(output_file_h2, "w").close()

# We'll track the last header written for each output file.
#last_header = {"hap_1": None, "hap_2": None}
header=None
# Process each row.
for idx, row in df.iterrows():
    # --- Decide output file based solely on row[5] ---
    # Use row[5].strip() to remove leading/trailing spaces.
    rec_key = str(row[5]).strip()

    # Decide output file: if rec_key contains "H2", use hap_2; if it contains "H1", use hap_1.
    if "H2" in rec_key:
        current_path = output_file_h2
        record = fasta_dict.get(rec_key)
    elif "H1" in rec_key:
        current_path = output_file_h1
        record = fasta_dict.get(rec_key)
    else:
        with open(current_path, "a") as outf:
            outf.write("N" * 100)


    try:
        start_idx = int(row[6])
        end_idx = int(row[7])
    except:
        continue

    sign = str(row[8]).strip()
    if sign == '+':
        seq_str = str(record.seq[start_idx - 1: end_idx])
    elif sign == '-':
        seq_str = str(record.seq[end_idx: start_idx-1:-1])
    else:
        print(f"Unrecognized strand '{sign}' on row {idx}.")
        continue


    # --- Determine header from row[14] (if provided) ---
    if len(row) > 14 and pd.notna(row[14])and header != str(row[14]) :
      header = str(row[14])
      # Remove the substring if present.
      if "_Hap_1" in header:
        with open(current_path, "a") as outf:
          outf.write("\n")
          processed_header = header.replace("_Hap_1", "")
          outf.write(f">{processed_header}\n")
          outf.write(seq_str)
      elif "_Hap_2" in header:
        with open(current_path, "a") as outf:
          outf.write("\n")
          processed_header = header.replace("_Hap_2", "")
          outf.write(f">{processed_header}\n")
          outf.write(seq_str)
    elif header == str(row[14]) and rec_key!='100':
      with open(current_path, "a") as outf:
        outf.write(seq_str)
    elif pd.isna(row[14]):
      with open(current_path, "a") as outf:
        outf.write("\n")
        outf.write(str(row[5]))
        outf.write("\n")
        outf.write(seq_str)


# Print contents.
print("Contents of Hap_1.fasta:")
with open(output_file_h1, "r") as f:
    print(f.read())

print("\nContents of Hap_2.fasta:")
with open(output_file_h2, "r") as f:
    print(f.read())
# Out:
# Contents of Hap_1.fasta:
#
# >Super1
# AAACCCGGGGNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNGGGAAAAAAGNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNGGGGGGAAAA
# >Super_2_Unloc_1
# GGGGGGAAAA
# H1.scaffold_1099
# AAAAAAAAAA
# H1.scaffold_1132
# GGGGGGGGGG
#
# Contents of Hap_2.fasta:
#
# >Super1
# GGGCCCAAAANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNCCCCAAAAAANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# H2.scaffold_542
# CCCGGGAAAA
# <ipython-input-14-d67b9d81cf59>:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rec_key = str(row[5]).strip()
# <ipython-input-14-d67b9d81cf59>:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start_idx = int(row[6])
# <ipython-input-14-d67b9d81cf59>:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end_idx = int(row[7])
# <ipython-input-14-d67b9d81cf59>:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sign = str(row[8]).strip()
# <ipython-input-14-d67b9d81cf59>:63: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if len(row) > 14 and pd.notna(row[14])and header != str(row[14]) :
# <ipython-input-14-d67b9d81cf59>:64: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   header = str(row[14])
# <ipython-input-14-d67b9d81cf59>:78: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif header == str(row[14]) and rec_key!='100':
# <ipython-input-14-d67b9d81cf59>:81: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif pd.isna(row[14]):
# <ipython-input-14-d67b9d81cf59>:84: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   outf.write(str(row[5]))

# %%
df
# Out:
#           Object  Object_begin  Object_end  Part_number Component_type  \
# 0     Scaffold_1             1          10            1              W
# 1     Scaffold_1            11          20            2              U
# 2     Scaffold_1            11          20            3              W
# 3     Scaffold_1            21          30            4              U
# 4     Scaffold_1            21          30            5              W
# 5     Scaffold_2             1          10            1              W
# 6     Scaffold_2            11          20            2              U
# 7     Scaffold_2            21          30            3              W
# 8     Scaffold_2            31          40            4              U
# 9     Scaffold_2            41          50            5              W
# 10  Scaffold_600             1          10            1              W
# 11  Scaffold_601             1          10            1              W
# 12  Scaffold_609             1          10            1              W
#
#         Component_id Component_begin Component_end         Orientation  \
# 0      H1.scaffold_1               1            10                   +
# 1                100        scaffold           yes  proximity_ligation
# 2      H1.scaffold_1              11            20                   -
# 3                100        scaffold           yes  proximity_ligation
# 4      H1.scaffold_1              21            30                   +
# 5      H2.scaffold_1               1            10                   +
# 6                100        scaffold           yes  proximity_ligation
# 7      H2.scaffold_1              11            20                   -
# 8                100        scaffold           yes  proximity_ligation
# 9      H2.scaffold_1              21            30                   +
# 10  H1.scaffold_1099               1            10                   +
# 11  H1.scaffold_1132               1            10                   +
# 12   H2.scaffold_542               1            10                   +
#
#         mod  paint  hap  ex1  ex2               Group_ID
# 0   Painted  Hap_1  NaN  NaN  NaN           Super1_Hap_1
# 1       NaN    NaN  NaN  NaN  NaN           Super1_Hap_1
# 2   Painted    NaN  NaN  NaN  NaN           Super1_Hap_1
# 3       NaN    NaN  NaN  NaN  NaN           Super1_Hap_1
# 4   Painted    NaN  NaN  NaN  NaN           Super1_Hap_1
# 5   Painted  Hap_2  NaN  NaN  NaN           Super1_Hap_2
# 6       NaN    NaN  NaN  NaN  NaN           Super1_Hap_2
# 7   Painted    NaN  NaN  NaN  NaN           Super1_Hap_2
# 8       NaN    NaN  NaN  NaN  NaN           Super1_Hap_2
# 9   Painted    NaN  NaN  NaN  NaN  Super_2_Hap_1_Unloc_1
# 10      NaN    NaN  NaN  NaN  NaN                    NaN
# 11      NaN    NaN  NaN  NaN  NaN                    NaN
# 12      NaN    NaN  NaN  NaN  NaN                    NaN
